# %% [markdown]
# <a href="https://colab.research.google.com/github/Koushik2612/fds-lab/blob/main/exp_5_dslab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Read Titanic dataset
df = pd.read_csv('/content/Titanic-Dataset (1).csv')

# Display first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Shape of dataset:", df.shape)

print("\nColumn names:")
print(df.columns)

print("\nData types:")
print(df.dtypes)

print("\nStatistical summary:")
print(df.describe())
# Out:
# Shape of dataset: (891, 12)
#
# Column names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Data types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# Statistical summary:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Age
age = df['Age'].dropna()

age_range = age.max() - age.min()

print("Age Range:", age_range)

# Fare
fare = df['Fare'].dropna()

fare_range = fare.max() - fare.min()

print("Fare Range:", fare_range)
# Out:
# Age Range: 79.58
# Fare Range: 512.3292

# %%
print("Age Variance:", age.var())
print("Fare Variance:", fare.var())
# Out:
# Age Variance: 211.0191247463081
# Fare Variance: 2469.436845743117

# %%
print("Age Standard Deviation:", age.std())
print("Fare Standard Deviation:", fare.std())
# Out:
# Age Standard Deviation: 14.526497332334044
# Fare Standard Deviation: 49.693428597180905

# %%
# Age
Q1_age = age.quantile(0.25)
Q3_age = age.quantile(0.75)
IQR_age = Q3_age - Q1_age

print("Age Q1:", Q1_age)
print("Age Q3:", Q3_age)
print("Age IQR:", IQR_age)

# Fare
Q1_fare = fare.quantile(0.25)
Q3_fare = fare.quantile(0.75)
IQR_fare = Q3_fare - Q1_fare

print("\nFare Q1:", Q1_fare)
print("Fare Q3:", Q3_fare)
print("Fare IQR:", IQR_fare)
# Out:
# Age Q1: 20.125
# Age Q3: 38.0
# Age IQR: 17.875
#
# Fare Q1: 7.9104
# Fare Q3: 31.0
# Fare IQR: 23.0896

# %%
age_cv = (age.std() / age.mean()) * 100
fare_cv = (fare.std() / fare.mean()) * 100

print("Age Coefficient of Variation:", age_cv, "%")
print("Fare Coefficient of Variation:", fare_cv, "%")
# Out:
# Age Coefficient of Variation: 48.912218554656754 %
# Fare Coefficient of Variation: 154.307252784085 %

# %%
plt.figure(figsize=(8,5))

plt.hist(age, bins=20, edgecolor='black')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Passenger Age')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(fare, bins=30, edgecolor='black')

plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Passenger Fare')

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=age)

plt.xlabel('Age')
plt.title('Box Plot of Age')

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=fare)

plt.xlabel('Fare')
plt.title('Box Plot of Fare')

plt.show()
